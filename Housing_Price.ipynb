# %%
import pandas as pd

# %%
import numpy as np

# %%
data=pd.read_csv('Mumbai_Property.csv')
data
# Out:
#                      Property_Name  \
# 0                Omkar Alta Monte
# 1     T Bhimjyani Neelkanth Woods
# 2          Legend 1 Pramila Nagar
# 3                 Unnamed Property
# 4                 Unnamed Property
# ...                            ...
# 2575           Shagun White Woods
# 2576                   Guru Anant
# 2577        Balaji Mayuresh Delta
# 2578        Balaji Mayuresh Delta
# 2579      Gurukrupa Tulsi Heights
#
#                                                Location            Region  \
# 0                         W E Highway Malad East Mumbai      Malad Mumbai
# 1                                  Manpada Thane Mumbai     Manpada Thane
# 2                                   Dahisar West Mumbai    Dahisar Mumbai
# 3     Vidyavihar West Vidyavihar West Central Mumbai...    Central Mumbai
# 4     176 Cst Road Kalina Mumbai 400098 Santacruz Ea...  Santacruz Mumbai
# ...                                                 ...               ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Property_Name  2580 non-null   object
#  1   Location       2580 non-null   object
#  2   Region         2580 non-null   object
#  3   Property_Age   2580 non-null   object
#  4   Availability   2580 non-null   object
#  5   Area_Tpye      2580 non-null   object
#  6   Area_SqFt      2580 non-null   float64
#  7   Rate_SqFt      2580 non-null   int64
#  8   Floor_No       2580 non-null   int64
#  9   Bedroom        2580 non-null   int64
#  10  Bathroom       2580 non-null   int64
#  11  Price_Lakh     2580 non-null   float64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 242.0+ KB

# %%
data.describe()
# Out:
#            Area_SqFt     Rate_SqFt     Floor_No      Bedroom     Bathroom  \
# count    2580.000000  2.580000e+03  2580.000000  2580.000000  2580.000000
# mean     1026.105058  1.911185e+04     8.839535     1.962016     2.066667
# std      2287.126278  4.076088e+04     8.100081     0.844726     0.749960
# min        33.570000  8.400000e+01    -1.000000     1.000000     1.000000
# 25%       630.750000  8.791750e+03     3.000000     1.000000     2.000000
# 50%       850.000000  1.378500e+04     6.000000     2.000000     2.000000
# 75%      1156.000000  2.265000e+04    12.000000     2.000000     2.000000
# max    100000.000000  1.650000e+06    59.000000     6.000000     7.000000
#
#          Price_Lakh
# count   2580.000000
# mean     174.389806
# std      369.484393
# min       13.000000
# 25%       67.000000
# 50%      111.500000
# 75%      200.000000
# max    16500.000000

# %%
data.head()
# Out:
#                   Property_Name  \
# 0             Omkar Alta Monte
# 1  T Bhimjyani Neelkanth Woods
# 2       Legend 1 Pramila Nagar
# 3              Unnamed Property
# 4              Unnamed Property
#
#                                             Location            Region  \
# 0                      W E Highway Malad East Mumbai      Malad Mumbai
# 1                               Manpada Thane Mumbai     Manpada Thane
# 2                                Dahisar West Mumbai    Dahisar Mumbai
# 3  Vidyavihar West Vidyavihar West Central Mumbai...    Central Mumbai
# 4  176 Cst Road Kalina Mumbai 400098 Santacruz Ea...  Santacruz Mumbai
#
#    Property_Age   Availability            Area_Tpye  Area_SqFt  Rate_SqFt  \
# 0   0 to 1 Year  Ready To Move  Super Built Up Area     2900.0      17241
# 1   1 to 5 Year  Ready To Move  Super Built Up Area     1900.0      12631
# 2      10+ Year  Ready To Move  Super Built Up Area      595.0      15966
# ...

# %%
data.tail()
# Out:
#                  Property_Name                           Location  \
# 2575       Shagun White Woods   Sector 23 Ulwe Navi Mumbai Mumbai
# 2576               Guru Anant    Sector 2 Ulwe Navi Mumbai Mumbai
# 2577    Balaji Mayuresh Delta             Ulwe Navi Mumbai Mumbai
# 2578    Balaji Mayuresh Delta             Ulwe Navi Mumbai Mumbai
# 2579  Gurukrupa Tulsi Heights             Ulwe Navi Mumbai Mumbai
#
#                 Region Property_Age   Availability      Area_Tpye  Area_SqFt  \
# 2575  Ulwe Navi-Mumbai  1 to 5 Year  Ready To Move  Built Up Area     1180.0
# 2576  Ulwe Navi-Mumbai  0 to 1 Year  Ready To Move  Built Up Area     1090.0
# 2577  Ulwe Navi-Mumbai  1 to 5 Year  Ready To Move  Built Up Area     1295.0
# 2578  Ulwe Navi-Mumbai  1 to 5 Year  Ready To Move  Built Up Area     1850.0
# 2579  Ulwe Navi-Mumbai  0 to 1 Year  Ready To Move  Built Up Area     1100.0
#
#       Rate_SqFt  Floor_No  Bedroom  Bathroom  Price_Lakh
# ...

# %%
data.isnull().sum()
# Out:
# Property_Name    0
# Location         0
# Region           0
# Property_Age     0
# Availability     0
# Area_Tpye        0
# Area_SqFt        0
# Rate_SqFt        0
# Floor_No         0
# Bedroom          0
# Bathroom         0
# Price_Lakh       0
# dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
data.Availability.value_counts()
# Out:
# Availability
# Ready To Move         2565
# Under Construction      15
# Name: count, dtype: int64

# %%
data.Region.value_counts().head(20)
# Out:
# Region
# Central Mumbai               225
# Mira Road                    201
# Kharghar Navi-Mumbai         196
# Thane                        192
# Ulwe Navi-Mumbai             174
# Mumbai Harbour               104
# South Mumbai                  98
# Dombivli Thane                85
# Hiranandani Thane             79
# Ghansoli Navi-Mumbai          76
# Kamothe Navi-Mumbai           64
# Kandivali Mumbai              62
# Panvel Navi-Mumbai            61
# Malad Mumbai                  59
# Kalyan Thane                  58
# Andheri Mumbai                46
# Taloja Navi-Mumbai            44
# Manpada Thane                 42
# Koparkhairane Navi-Mumbai     39
# Borivali Mumbai               33
# Name: count, dtype: int64

# %%
data.Region.nunique()
# Out:
# 145

# %%
plt.figure(figsize=(10,40))
window_num=1
for i in data:
    plt.subplot(6,2,window_num)
    sns.histplot(x=i,data=data,kde=True,hue='Availability')
    window_num +=1

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.histplot(x='Area_SqFt',data=data,kde=True,hue='Availability')
# Out:
# <Axes: xlabel='Area_SqFt', ylabel='Count'>

# %%
sns.boxplot(x='Area_SqFt',data=data)
# Out:
# <Axes: xlabel='Area_SqFt'>

# %%
num_data=data.select_dtypes(['int','float']).columns
num_data
# Out:
# Index(['Area_SqFt', 'Rate_SqFt', 'Floor_No', 'Bedroom', 'Bathroom',
#        'Price_Lakh'],
#       dtype='object')

# %%
sns.pairplot(data)
plt.show()

# %%
sns.scatterplot(x='Area_SqFt',y=i,hue='Availability',data=data)
# Out:
# <Axes: xlabel='Area_SqFt', ylabel='Price_Lakh'>

# %%
data[num_data].isnull().sum()
# Out:
# Area_SqFt     0
# Rate_SqFt     0
# Floor_No      0
# Bedroom       0
# Bathroom      0
# Price_Lakh    0
# dtype: int64

# %%
plt.figure(figsize=(6,8))
window_num=1
for i in data[num_data]:
    plt.subplot(3,2,window_num)
    sns.boxplot(x=i,data=data) #using boxplot you know the outlier
    window_num += 1
plt.tight_layout()

# %%
data.loc[data.Area_SqFt >= 40000,'Area_SqFt']
# Out:
# 1201    100000.0
# 1418     49454.0
# Name: Area_SqFt, dtype: float64

# %%
data.Area_SqFt.astype('int64')
# Out:
# 0       2900
# 1       1900
# 2        595
# 3       1450
# 4        876
#         ...
# 2575    1180
# 2576    1090
# 2577    1295
# 2578    1850
# 2579    1100
# Name: Area_SqFt, Length: 2580, dtype: int64

# %%
data.Area_SqFt=data.Area_SqFt.astype('int64')

# %%
data.Area_SqFt
# Out:
# 0       2900
# 1       1900
# 2        595
# 3       1450
# 4        876
#         ...
# 2575    1180
# 2576    1090
# 2577    1295
# 2578    1850
# 2579    1100
# Name: Area_SqFt, Length: 2580, dtype: int64

# %%
data.duplicated().sum()
# Out:
# 7

# %%
data.shape
# Out:
# (2580, 12)

# %%
col_name="Property_Name"
dup_val=data[data['Property_Name'].duplicated()]

# %%
dup_val
# Out:
#                Property_Name  \
# 4           Unnamed Property
# 6           Unnamed Property
# 7           Unnamed Property
# 8           Unnamed Property
# 12          Unnamed Property
# ...                      ...
# 2573        Unnamed Property
# 2574  Balaji Mayuresh Delta
# 2575     Shagun White Woods
# 2577  Balaji Mayuresh Delta
# 2578  Balaji Mayuresh Delta
#
#                                                Location  \
# 4     176 Cst Road Kalina Mumbai 400098 Santacruz Ea...
# 6     V P Road Near Q Deck Family Restaurant And Bar...
# 7              Nahur East Central Mumbai suburbs Mumbai
# 8                Kalyan East Mumbai Beyond Thane Mumbai
# 12                                402 Malad West Mumbai
# ...                                                 ...
# 2573                   Koparkhairane Navi Mumbai Mumbai
# 2574                            Ulwe Navi Mumbai Mumbai
# 2575                  Sector 23 Ulwe Navi Mumbai Mumbai
# ...

# %%
data=data.drop_duplicates(ignore_index=True)

# %%
data.shape
# Out:
# (2573, 12)

# %%
plt.figure(figsize=(10,40))
window_num=1
for i in data:
    plt.subplot(6,2,window_num)
    sns.histplot(x=i,data=data,kde=True,hue='Availability')
    window_num += 1
plt.tight_layout()

# %%
# correlation with price_lakh

# %%
data.dtypes
# Out:
# Property_Name     object
# Location          object
# Region            object
# Property_Age      object
# Availability      object
# Area_Tpye         object
# Area_SqFt          int64
# Rate_SqFt          int64
# Floor_No           int64
# Bedroom            int64
# Bathroom           int64
# Price_Lakh       float64
# dtype: object

# %%
data.Price_Lakh.astype('int64')
# Out:
# 0       500
# 1       240
# 2        95
# 3       375
# 4       350
#        ...
# 2568    122
# 2569     88
# 2570    137
# 2571    171
# 2572     95
# Name: Price_Lakh, Length: 2573, dtype: int64

# %%
data.Price_Lakh=data.Price_Lakh.astype('int64')

# %%
num_data=data.select_dtypes(include=['float64','int64'])

# %%
correlation_matrix=num_data.corr()
correlation_matrix
# Out:
#             Area_SqFt  Rate_SqFt  Floor_No   Bedroom  Bathroom  Price_Lakh
# Area_SqFt    1.000000  -0.018427  0.026592  0.215386  0.220824    0.083972
# Rate_SqFt   -0.018427   1.000000  0.098888  0.104956  0.107410    0.785564
# Floor_No     0.026592   0.098888  1.000000  0.296833  0.292184    0.160221
# Bedroom      0.215386   0.104956  0.296833  1.000000  0.842087    0.324671
# Bathroom     0.220824   0.107410  0.292184  0.842087  1.000000    0.321116
# Price_Lakh   0.083972   0.785564  0.160221  0.324671  0.321116    1.000000

# %%
target_correlation=num_data.corr()['Price_Lakh'].sort_values(ascending=False)

# %%
target_correlation.head(10)
# Out:
# Price_Lakh    1.000000
# Rate_SqFt     0.785564
# Bedroom       0.324671
# Bathroom      0.321116
# Floor_No      0.160221
# Area_SqFt     0.083972
# Name: Price_Lakh, dtype: float64

# %%
data.to_csv('Cleaned_Mumbai_Property.csv')
